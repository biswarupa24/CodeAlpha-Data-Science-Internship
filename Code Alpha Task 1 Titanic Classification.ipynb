# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# %%
#Load Data
df = pd.read_csv(r"C:\Users\senap\Downloads\titanic\train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(df.shape)
# Out:
# (891, 12)

# %%
sns.heatmap(df.corr(), cmap = "YlGnBu")
plt.show()
# Out:
# C:\Users\senap\AppData\Local\Temp\ipykernel_15224\1821895278.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap = "YlGnBu")

# %%
#Columns to drop
df = df.drop(['Name', 'Cabin', 'Ticket'], axis = 1)

# %%
#Checking for Missing Values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna('S', inplace = True)

# %%
df=df.fillna(df.mean())
# Out:
# C:\Users\senap\AppData\Local\Temp\ipykernel_15224\3358723971.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Type Casting
df['Age'] = df['Age'].astype('int64')
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Fare           float64
# Embarked        object
# dtype: object

# %%
#Checking for Duplicates
duplicates = df.duplicated().sum()
duplicates
# Out:
# 0

# %%
#Finding the number of prople survied or not
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#Count Plot
sns.countplot(x ='Survived', data = df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
#Encoding the categorical column
df.replace({'Sex': {'male': 0, 'female': 1}, 'Embarked': {'S': 0, 'C': 1, 'Q': 2}}, inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    0   22      1      0   7.2500         0
# 1              2         1       1    1   38      1      0  71.2833         1
# 2              3         1       3    1   26      0      0   7.9250         0
# 3              4         1       1    1   35      1      0  53.1000         0
# 4              5         0       3    0   35      0      0   8.0500         0
# ..           ...       ...     ...  ...  ...    ...    ...      ...       ...
# 886          887         0       2    0   27      0      0  13.0000         0
# 887          888         1       1    1   19      0      0  30.0000         0
# 888          889         0       3    1   29      1      2  23.4500         0
# 889          890         1       1    0   26      0      0  30.0000         1
# 890          891         0       3    0   32      0      0   7.7500         2
#
# [891 rows x 9 columns]

# %%
sns.countplot(x ='Sex', hue = 'Survived', data = df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
#Pairplot
sns.pairplot(df)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0   22      1      0   7.2500         0
# 1            2         1       1    1   38      1      0  71.2833         1
# 2            3         1       3    1   26      0      0   7.9250         0
# 3            4         1       1    1   35      1      0  53.1000         0
# 4            5         0       3    0   35      0      0   8.0500         0

# %%
#Split the dataset into Train data and Test data
x = df[['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]
y = df[['Survived']]

# %%
#Split the dataset into Train data and Test data
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state = 2)

print('Train data: ', X_train.shape, Y_train.shape)
print('Test data: ', X_test.shape, Y_test.shape)
# Out:
# Train data:  (712, 8) (712, 1)
# Test data:  (179, 8) (179, 1)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
classifier = DecisionTreeClassifier()

# %%
classifier.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
accuracy_score(y_pred, Y_test)
# Out:
# 0.7653631284916201

# %%
df_new = pd.read_csv(r"C:\Users\senap\Downloads\titanic\test.csv")

# %%
#Columns to drop
df_new = df_new.drop(['Name', 'Cabin', 'Ticket'], axis = 1)

# %%
df_new.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Fare            1
# Embarked        0
# dtype: int64

# %%
passengerId = df_new['PassengerId'].values

# %%
df_new['Fare'].fillna(df_new['Fare'].mean(), inplace = True)
df_new = df_new.fillna(df_new.mean())
df_new['Age'] = df_new['Age'].astype('int64')
df_new.replace({'Sex': {'male': 0, 'female': 1}, 'Embarked': {'S': 0, 'C': 1, 'Q': 2}}, inplace=True)
# Out:
# C:\Users\senap\AppData\Local\Temp\ipykernel_15224\334095139.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_new = df_new.fillna(df_new.mean())

# %%
x_final = df_new.iloc[:,:].values

# %%
y_final = classifier.predict(x_final)
# Out:
# C:\Users\senap\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
y_final.shape
# Out:
# (418,)

# %%
passengerId.shape
# Out:
# (418,)

# %%
final = pd.DataFrame()

# %%
final['passengerId'] = passengerId
final['Survived'] = y_final

# %%
final.to_csv('Finalsubmission.csv',index = False)
